# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
# %matplotlib inline 

df=pd.read_csv("Cleaned.csv")
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI   Classes  Region
# 0  1.3  3.4  0.5  not fire       0
# 1  1.0  3.9  0.4  not fire       0
# 2  0.3  2.7  0.1  not fire       0
# 3  0.0  1.7  0.0  not fire       0
# 4  1.2  3.9  0.5  not fire       0

# %%
df.drop(["Unnamed: 0", "day", "month", "year"], axis=1, inplace=True)
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire       0

# %%
#predition of fwi needs to be done

df['Classes'] = df['Classes'].replace({'not fire': 0, 'fire': 1})
df["Classes"].value_counts()
# Out:
# C:\Users\LIZA CASTELINA\AppData\Local\Temp\ipykernel_14112\4085984123.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Classes'] = df['Classes'].replace({'not fire': 0, 'fire': 1})
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.hist(figsize=(15,10))
plt.show()

plt.scatter(df['Temperature'], df['RH'])
plt.show()

df['Classes'].value_counts().plot.pie()
plt.show()

# %%
df.info()
df.describe()
df.head()
df.fillna()
df.replacena()
df.drop()
df.dropna()
df.unique()
df.tail()
df.isnull()
